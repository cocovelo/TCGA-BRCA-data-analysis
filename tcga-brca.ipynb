# %%
import pandas as pd

df = pd.read_csv("C:/Users/colin/PycharmProjects/PythonProject/tcga-brca-project/tcga-brca-vst-normalized-counts.csv", index_col=0)
metadata_df = pd.read_csv("C:/Users/colin/PycharmProjects/PythonProject/tcga-brca-project/tcga_brca_sample_metadata.csv", index_col=0)

# %%
df.head()
metadata_df.head()
# Out:
#                                                    barcode       patient  \
# TCGA-GM-A2DL-01A-11R-A18M-07  TCGA-GM-A2DL-01A-11R-A18M-07  TCGA-GM-A2DL
# TCGA-AC-A2QI-01A-12R-A19W-07  TCGA-AC-A2QI-01A-12R-A19W-07  TCGA-AC-A2QI
# TCGA-EW-A1PD-01A-11R-A144-07  TCGA-EW-A1PD-01A-11R-A144-07  TCGA-EW-A1PD
# TCGA-AR-A24N-01A-11R-A169-07  TCGA-AR-A24N-01A-11R-A169-07  TCGA-AR-A24N
# TCGA-AR-A24U-01A-11R-A169-07  TCGA-AR-A24U-01A-11R-A169-07  TCGA-AR-A24U
#
#                                         sample shortLetterCode  \
# TCGA-GM-A2DL-01A-11R-A18M-07  TCGA-GM-A2DL-01A              TP
# TCGA-AC-A2QI-01A-12R-A19W-07  TCGA-AC-A2QI-01A              TP
# TCGA-EW-A1PD-01A-11R-A144-07  TCGA-EW-A1PD-01A              TP
# TCGA-AR-A24N-01A-11R-A169-07  TCGA-AR-A24N-01A              TP
# TCGA-AR-A24U-01A-11R-A169-07  TCGA-AR-A24U-01A              TP
#
#                                        definition sample_submitter_id  \
# TCGA-GM-A2DL-01A-11R-A18M-07  Primary solid Tumor    TCGA-GM-A2DL-01A
# TCGA-AC-A2QI-01A-12R-A19W-07  Primary solid Tumor    TCGA-AC-A2QI-01A
# TCGA-EW-A1PD-01A-11R-A144-07  Primary solid Tumor    TCGA-EW-A1PD-01A
# TCGA-AR-A24N-01A-11R-A169-07  Primary solid Tumor    TCGA-AR-A24N-01A
# TCGA-AR-A24U-01A-11R-A169-07  Primary solid Tumor    TCGA-AR-A24U-01A
#
#                               sample_type_id tumor_descriptor  \
# TCGA-GM-A2DL-01A-11R-A18M-07               1          Primary
# TCGA-AC-A2QI-01A-12R-A19W-07               1          Primary
# TCGA-EW-A1PD-01A-11R-A144-07               1          Primary
# TCGA-AR-A24N-01A-11R-A169-07               1          Primary
# TCGA-AR-A24U-01A-11R-A169-07               1          Primary
#
#                                                          sample_id  \
# TCGA-GM-A2DL-01A-11R-A18M-07  d6e981ee-1afc-4f84-a3be-e87e0d1460cd
# TCGA-AC-A2QI-01A-12R-A19W-07  08f10bb1-6dd4-4f36-86a3-1801f9762187
# TCGA-EW-A1PD-01A-11R-A144-07  9f52ae8b-7fe7-441c-9fb6-c55a9bd1a0d0
# TCGA-AR-A24N-01A-11R-A169-07  dcc31bf1-9890-4fb1-9677-b5fb77e1fc37
# TCGA-AR-A24U-01A-11R-A169-07  17cdb451-9b35-4aab-8bc2-b4a64ef3e3b4
#
#                                 sample_type  ...  \
# TCGA-GM-A2DL-01A-11R-A18M-07  Primary Tumor  ...
# TCGA-AC-A2QI-01A-12R-A19W-07  Primary Tumor  ...
# TCGA-EW-A1PD-01A-11R-A144-07  Primary Tumor  ...
# TCGA-AR-A24N-01A-11R-A169-07  Primary Tumor  ...
# TCGA-AR-A24U-01A-11R-A169-07  Primary Tumor  ...
#
#                              paper_tobacco_smoking_history  \
# TCGA-GM-A2DL-01A-11R-A18M-07                           NaN
# TCGA-AC-A2QI-01A-12R-A19W-07                           NaN
# TCGA-EW-A1PD-01A-11R-A144-07                           NaN
# TCGA-AR-A24N-01A-11R-A169-07                           NaN
# TCGA-AR-A24U-01A-11R-A169-07                           NaN
#
#                               paper_CNV.Clusters paper_Mutation.Clusters  \
# TCGA-GM-A2DL-01A-11R-A18M-07                  C3                      C1
# TCGA-AC-A2QI-01A-12R-A19W-07                  C1                      C4
# TCGA-EW-A1PD-01A-11R-A144-07                 NaN                     NaN
# TCGA-AR-A24N-01A-11R-A169-07                  C1                      C1
# TCGA-AR-A24U-01A-11R-A169-07                  C4                      C4
#
#                               paper_DNA.Methylation.Clusters  \
# TCGA-GM-A2DL-01A-11R-A18M-07                              C2
# TCGA-AC-A2QI-01A-12R-A19W-07                              C1
# TCGA-EW-A1PD-01A-11R-A144-07                             NaN
# TCGA-AR-A24N-01A-11R-A169-07                              C2
# TCGA-AR-A24U-01A-11R-A169-07                              C1
#
#                              paper_mRNA.Clusters paper_miRNA.Clusters  \
# TCGA-GM-A2DL-01A-11R-A18M-07                  C1                   C2
# TCGA-AC-A2QI-01A-12R-A19W-07                  C2                   C2
# TCGA-EW-A1PD-01A-11R-A144-07                 NaN                  NaN
# TCGA-AR-A24N-01A-11R-A169-07                  C1                   C3
# TCGA-AR-A24U-01A-11R-A169-07                  C2                   C3
#
#                              paper_lncRNA.Clusters  paper_Protein.Clusters  \
# TCGA-GM-A2DL-01A-11R-A18M-07                    C1                      C2
# TCGA-AC-A2QI-01A-12R-A19W-07                   NaN                      C1
# TCGA-EW-A1PD-01A-11R-A144-07                   NaN                     NaN
# TCGA-AR-A24N-01A-11R-A169-07                    C2                      C1
# TCGA-AR-A24U-01A-11R-A169-07                    C1                      C1
#
#                              paper_PARADIGM.Clusters  paper_Pan.Gyn.Clusters
# TCGA-GM-A2DL-01A-11R-A18M-07                      C5                      C3
# TCGA-AC-A2QI-01A-12R-A19W-07                      C6                      C1
# TCGA-EW-A1PD-01A-11R-A144-07                     NaN                     NaN
# TCGA-AR-A24N-01A-11R-A169-07                      C5                      C1
# TCGA-AR-A24U-01A-11R-A169-07                      C4                      C3
#
# [5 rows x 96 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

X = df.T

# %%
common_samples = list(set(X.index) & set(metadata_df.index))
X = X.loc[common_samples].sort_index()

meta_df = metadata_df.loc[common_samples].sort_index()

print(f"\nExpression Data Shape (Samples x Genes): {X.shape}")
print(f"Metadata Shape (Samples x Features): {meta_df.shape}")
print(f"Are all sample IDs aligned? {all(X.index == meta_df.index)}")
# Out:
# Expression Data Shape (Samples x Genes): (885, 18303)
# Metadata Shape (Samples x Features): (885, 96)
# Are all sample IDs aligned? True

# %%
print("\nAligned Expression Data (First 5 Sample IDs):")
print(X.index[:5].tolist())
print("\nAligned Metadata (First 5 Sample IDs):")
print(meta_df.index[:5].tolist())
# Out:
# Aligned Expression Data (First 5 Sample IDs):
# ['TCGA-A1-A0SB-01A-11R-A144-07', 'TCGA-A1-A0SF-01A-11R-A144-07', 'TCGA-A1-A0SG-01A-11R-A144-07', 'TCGA-A1-A0SI-01A-11R-A144-07', 'TCGA-A1-A0SN-01A-11R-A144-07']
#
# Aligned Metadata (First 5 Sample IDs):
# ['TCGA-A1-A0SB-01A-11R-A144-07', 'TCGA-A1-A0SF-01A-11R-A144-07', 'TCGA-A1-A0SG-01A-11R-A144-07', 'TCGA-A1-A0SI-01A-11R-A144-07', 'TCGA-A1-A0SN-01A-11R-A144-07']

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
print("\nScaled Expression Data (Head):")
print(X_scaled.head())
# Out:
# Scaled Expression Data (Head):
#                               ENSG00000000003.15  ENSG00000000419.13  \
# TCGA-A1-A0SB-01A-11R-A144-07            0.901053           -1.107678
# TCGA-A1-A0SF-01A-11R-A144-07            1.964514           -0.397228
# TCGA-A1-A0SG-01A-11R-A144-07            0.225169           -0.483863
# TCGA-A1-A0SI-01A-11R-A144-07           -0.125770            0.258707
# TCGA-A1-A0SN-01A-11R-A144-07           -1.736456            2.242947
#
#                               ENSG00000000457.14  ENSG00000000460.17  \
# TCGA-A1-A0SB-01A-11R-A144-07           -0.537444           -0.635950
# TCGA-A1-A0SF-01A-11R-A144-07           -0.042405           -0.195591
# TCGA-A1-A0SG-01A-11R-A144-07           -0.875888           -0.593551
# TCGA-A1-A0SI-01A-11R-A144-07            1.146420            1.751878
# TCGA-A1-A0SN-01A-11R-A144-07            0.415368            0.513456
#
#                               ENSG00000000938.13  ENSG00000000971.16  \
# TCGA-A1-A0SB-01A-11R-A144-07           -1.712165            1.641017
# TCGA-A1-A0SF-01A-11R-A144-07            0.495801            0.193284
# TCGA-A1-A0SG-01A-11R-A144-07           -0.288065            0.206657
# TCGA-A1-A0SI-01A-11R-A144-07           -0.484578            1.066979
# TCGA-A1-A0SN-01A-11R-A144-07           -0.281046            0.466929
#
#                               ENSG00000001036.14  ENSG00000001084.13  \
# TCGA-A1-A0SB-01A-11R-A144-07           -1.947701           -0.473659
# TCGA-A1-A0SF-01A-11R-A144-07           -0.783097           -0.547196
# TCGA-A1-A0SG-01A-11R-A144-07           -0.147475            0.045047
# TCGA-A1-A0SI-01A-11R-A144-07            0.423888           -1.122231
# TCGA-A1-A0SN-01A-11R-A144-07            0.813513           -0.941770
#
#                               ENSG00000001167.14  ENSG00000001460.18  ...  \
# TCGA-A1-A0SB-01A-11R-A144-07           -0.056775            1.028051  ...
# TCGA-A1-A0SF-01A-11R-A144-07            0.310305            0.726930  ...
# TCGA-A1-A0SG-01A-11R-A144-07           -0.291072            0.944642  ...
# TCGA-A1-A0SI-01A-11R-A144-07            0.275946            0.495363  ...
# TCGA-A1-A0SN-01A-11R-A144-07           -0.541491           -0.964228  ...
#
#                               ENSG00000288559.1  ENSG00000288573.1  \
# TCGA-A1-A0SB-01A-11R-A144-07          -0.307253           0.485651
# TCGA-A1-A0SF-01A-11R-A144-07           0.813083           1.046818
# TCGA-A1-A0SG-01A-11R-A144-07          -0.157356           0.362826
# TCGA-A1-A0SI-01A-11R-A144-07           0.369557          -0.234208
# TCGA-A1-A0SN-01A-11R-A144-07           0.385831          -1.254426
#
#                               ENSG00000288585.1  ENSG00000288586.1  \
# TCGA-A1-A0SB-01A-11R-A144-07          -0.597459           0.475821
# TCGA-A1-A0SF-01A-11R-A144-07          -0.342963          -0.893049
# TCGA-A1-A0SG-01A-11R-A144-07           1.450317           0.324510
# TCGA-A1-A0SI-01A-11R-A144-07           0.039627           0.025419
# TCGA-A1-A0SN-01A-11R-A144-07          -0.012789          -0.766188
#
#                               ENSG00000288596.2  ENSG00000288598.1  \
# TCGA-A1-A0SB-01A-11R-A144-07          -0.164475           1.015015
# TCGA-A1-A0SF-01A-11R-A144-07          -0.998560           0.374208
# TCGA-A1-A0SG-01A-11R-A144-07           0.821322           0.011711
# TCGA-A1-A0SI-01A-11R-A144-07          -1.114945          -1.684796
# TCGA-A1-A0SN-01A-11R-A144-07          -2.041750          -0.608637
#
#                               ENSG00000288612.1  ENSG00000288663.1  \
# TCGA-A1-A0SB-01A-11R-A144-07          -0.416598           0.161732
# TCGA-A1-A0SF-01A-11R-A144-07          -0.737455          -0.252792
# TCGA-A1-A0SG-01A-11R-A144-07          -0.634214          -0.565149
# TCGA-A1-A0SI-01A-11R-A144-07          -0.289156          -0.683200
# TCGA-A1-A0SN-01A-11R-A144-07          -2.201589          -1.362445
#
#                               ENSG00000288670.1  ENSG00000288675.1
# TCGA-A1-A0SB-01A-11R-A144-07          -0.823509           0.279546
# TCGA-A1-A0SF-01A-11R-A144-07           0.568187           0.515681
# TCGA-A1-A0SG-01A-11R-A144-07           0.507903           0.916734
# TCGA-A1-A0SI-01A-11R-A144-07          -0.180042           0.558689
# TCGA-A1-A0SN-01A-11R-A144-07          -0.633294          -0.684025
#
# [5 rows x 18303 columns]

# %%
target_variable = 'paper_BRCA_Subtype_PAM50'
y_labels = meta_df[target_variable]
valid_indices = y_labels.dropna().index
X_knn = X_scaled.loc[valid_indices]
y_knn = y_labels.loc[valid_indices]

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_knn)

print(f"\nTarget Variable Unique Values ({target_variable}): {y_knn.unique()}")
print(f"Encoded Labels (First 5): {y_encoded[:5]}")
# Out:
# Target Variable Unique Values (paper_BRCA_Subtype_PAM50): ['Normal' 'LumA' 'LumB' 'Basal' 'Her2']
# Encoded Labels (First 5): [4 2 2 3 3]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_knn, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"\nTraining set size: {X_train.shape[0]} samples")
print(f"Test set size: {X_test.shape[0]} samples")
# Out:
# Training set size: 605 samples
# Test set size: 152 samples

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=label_encoder.classes_)
print(f"\nkNN Classification Accuracy: {accuracy:.4f}")
print("\nkNN Classification Report:\n", report)
# Out:
# kNN Classification Accuracy: 0.7566
#
# kNN Classification Report:
#                precision    recall  f1-score   support
#
#        Basal       0.96      0.90      0.93        29
#         Her2       0.67      0.20      0.31        10
#         LumA       0.74      0.98      0.84        82
#         LumB       0.83      0.20      0.32        25
#       Normal       0.25      0.33      0.29         6
#
#     accuracy                           0.76       152
#    macro avg       0.69      0.52      0.54       152
# weighted avg       0.77      0.76      0.72       152

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': range(1, 31)}
grid_search = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_knn, y_encoded)

print(f"\nBest k for kNN: {grid_search.best_params_['n_neighbors']}")
print(f"Best cross-validation accuracy: {grid_search.best_score_:.4f}")
# Out:
# Best k for kNN: 2
# Best cross-validation accuracy: 0.7623

# %%
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch.nn as nn
import torch.optim as optim

class GeneExpressionClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(GeneExpressionClassifier, self).__init__()
        self.layer1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.3)

        self.layer2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.3)

        self.output_layer = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.layer1(x)
        x = self.relu1(x)
        x = self.dropout1(x)

        x = self.layer2(x)
        x = self.relu2(x)
        x = self.dropout2(x)

        x = self.output_layer(x)
        return x

input_size = X_train.shape[1]
num_classes = len(label_encoder.classes_)
model = GeneExpressionClassifier(input_size, num_classes)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

print("\nNeural Network Model Architecture:")
print(model)
# Out:
# Neural Network Model Architecture:
# GeneExpressionClassifier(
#   (layer1): Linear(in_features=18303, out_features=256, bias=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (layer2): Linear(in_features=256, out_features=128, bias=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (output_layer): Linear(in_features=128, out_features=5, bias=True)
# )

# %%
num_epochs = 50
training_loss_history = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print(f"\nTraining on: {device}")

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(train_dataset)
    
    training_loss_history.append(epoch_loss)
    
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
# Out:
# Training on: cuda
# Epoch 1/50, Loss: 0.1703
# Epoch 2/50, Loss: 0.0501
# Epoch 3/50, Loss: 0.1827
# Epoch 4/50, Loss: 0.2141
# Epoch 5/50, Loss: 0.4709
# Epoch 6/50, Loss: 0.1637
# Epoch 7/50, Loss: 0.0875
# Epoch 8/50, Loss: 0.1148
# Epoch 9/50, Loss: 0.2077
# Epoch 10/50, Loss: 0.1074
# Epoch 11/50, Loss: 0.1539
# Epoch 12/50, Loss: 0.0677
# Epoch 13/50, Loss: 0.0854
# Epoch 14/50, Loss: 0.0669
# Epoch 15/50, Loss: 0.0158
# Epoch 16/50, Loss: 0.0870
# Epoch 17/50, Loss: 0.2604
# Epoch 18/50, Loss: 0.1469
# Epoch 19/50, Loss: 0.2072
# Epoch 20/50, Loss: 0.0140
# Epoch 21/50, Loss: 0.0268
# Epoch 22/50, Loss: 0.0000
# Epoch 23/50, Loss: 0.0744
# Epoch 24/50, Loss: 0.0118
# Epoch 25/50, Loss: 0.1043
# Epoch 26/50, Loss: 0.0055
# Epoch 27/50, Loss: 0.0000
# Epoch 28/50, Loss: 0.0035
# Epoch 29/50, Loss: 0.0016
# Epoch 30/50, Loss: 0.0242
# Epoch 31/50, Loss: 0.0162
# Epoch 32/50, Loss: 0.0001
# Epoch 33/50, Loss: 0.0340
# Epoch 34/50, Loss: 0.0000
# Epoch 35/50, Loss: 0.0102
# Epoch 36/50, Loss: 0.0654
# Epoch 37/50, Loss: 0.0319
# Epoch 38/50, Loss: 0.0288
# Epoch 39/50, Loss: 0.0002
# Epoch 40/50, Loss: 0.0002
# Epoch 41/50, Loss: 0.0046
# Epoch 42/50, Loss: 0.0483
# Epoch 43/50, Loss: 0.0311
# Epoch 44/50, Loss: 0.0001
# Epoch 45/50, Loss: 0.0274
# Epoch 46/50, Loss: 0.0088
# Epoch 47/50, Loss: 0.0000
# Epoch 48/50, Loss: 0.0291
# Epoch 49/50, Loss: 0.0000
# Epoch 50/50, Loss: 0.0401

# %%
model.eval()
correct = 0
total = 0
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

accuracy_dl = correct / total
report_dl = classification_report(all_labels, all_preds, target_names=label_encoder.classes_)

print(f"\nDeep Learning Classification Accuracy on Test Set: {accuracy_dl:.4f}")
print("\nDeep Learning Classification Report:\n", report_dl)
# Out:
# Deep Learning Classification Accuracy on Test Set: 0.8947
#
# Deep Learning Classification Report:
#                precision    recall  f1-score   support
#
#        Basal       0.91      1.00      0.95        29
#         Her2       0.75      0.90      0.82        10
#         LumA       0.94      0.94      0.94        82
#         LumB       0.86      0.72      0.78        25
#       Normal       0.60      0.50      0.55         6
#
#     accuracy                           0.89       152
#    macro avg       0.81      0.81      0.81       152
# weighted avg       0.89      0.89      0.89       152

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(training_loss_history) + 1)
plt.plot(epochs, training_loss_history, label='Training Loss')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('loss_curve.png')
plt.show()
